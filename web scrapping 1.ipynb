# %%
pip install lxml


#https://bit.ly/2NyxdAG
from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 250 data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
---------------------------------------------------------------------------------------------------------------------------------------------------


import  requests
from  bs4 import BeautifulSoup

url = requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(url.text, 'html.parser')
story = soup.find_all(['h1', 'h2','h3'])
for i in story:
    print(i)


pip install beautifulsoup4
---------------------------------------------------------------------------------------------------------------------------------------------



#https://bit.ly/2NyxdAG
from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 250 data
url = 'https://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 99):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
---------------------------------------------------------------------------------------------------------------
books.com code


pip install requests
pip install BeautifulSoup4
from bs4 import BeautifulSoup
pip install lxml

import requests ---vimp

html_text=requests.get('https://bookpage.com/reviews').text

soup=BeautifulSoup(html_text, 'html.parser')
book = soup.find_all('div' , class_ = 'row-fluid article-row' )
for books in book:
    
 book_name = books.find('h4' ,class_="italic").text
 print(f"Book name:{book_name.strip()}")
 author = books.find('p' ,class_="sans bold").text
 print(f"Author name:{author.strip()}")
 genre = books.find('p' ,class_ = "genre-links hidden-phone").text
 print(f"Genre:{genre.strip()}")
 review = books.find('p' ,class_="excerpt").text   
 print(f"Review:{review.strip()}")



----------------------------------------------------------
html_text=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi').text

soup=BeautifulSoup(html_text, 'html.parser')
book = soup.find('div' , class_="rankings-block__container full rankings-table")
print (book)







-------------------------------------------------------------------
icc q1 
a)html_text=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi').text

soup=BeautifulSoup(html_text, 'html.parser')
ranks = soup.find_all('td' , class_="table-body__cell rankings-table__team")

for rank in ranks:
    
 book_name = rank.find('td' ,class_="rankings-block__banner--matches")
 
 matches = rank.find('td' ,class_="table-body__cell u-text-right rating")
 print(matches)
 country= rank.find('span', class_="u-hide-phablet").text
 print(country)

b)html_text=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi').text

soup=BeautifulSoup(html_text, 'html.parser')
ranks = soup.find_all('div' , class_="u-negative-wrapper-tab uniform-grid touch-scroll-list--tablet")

for rank in ranks:
    
 book_name = rank.find('a' , href="/rankings/mens/player-rankings/164").text
 print(book_name)
 
 matches = rank.find('td' ,class_="table-body__cell u-text-right rating").text
 print(matches)
 country= rank.find('div', class_="rankings-block__banner--name").text
 print(country)
